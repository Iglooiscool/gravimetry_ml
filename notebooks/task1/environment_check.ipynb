# %% [markdown]
# # Environment Check

# %%
import sys
import platform
import os

# Checks python version
print("Python Version:", sys.version)
print("Platform:", platform.platform())

# Imports libraries outlined in project proposal
import numpy as np
import matplotlib
import pandas as pd
import scipy

# If code runs then each library has been imported properly
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("pandas:", pd.__version__)
print("scipy:", scipy.__version__)

# Checks container to ensure the interpreter is python
import gravimetry_ml
print("gravimetry_ml imports:OK")
# Out:
# Python Version: 3.11.15 (main, May 19 2026, 23:49:45) [GCC 14.2.0]
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.41
# numpy: 2.4.6
# matplotlib: 3.10.9
# pandas: 3.0.3
# scipy: 1.17.1
# gravimetry_ml imports:OK
