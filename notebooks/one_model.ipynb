# %% [markdown]
# # Official One-Model MLP
#
# Direct noisy gradient features to mask reconstruction. This notebook uses the Task 7 shape distribution, absolute Gaussian gradient noise, a 512-1024-2048 MLP, and sigmoid-plus-MSE mask training. The coordinate-aware decoder is not used here.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
while not (ROOT / 'src').exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

import torch
from config import OneModelRunConfig
from workflows.one_model import run_one_model

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
run_config = OneModelRunConfig(output_dir=ROOT / 'outputs' / 'one_model_mlp')
print('Device:', DEVICE)
print(run_config)

# %%
summary = run_one_model(run_config, device=DEVICE)
print('Test IoU:', summary['metrics']['test']['mean_iou'])
print('Fixed IoU:', summary['metrics']['fixed']['mean_iou'])
print('Outputs:', run_config.run_output_dir)
